# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
blue_lenna = Image.open("../../images/lenna.png")

# %%
blue_lenna

# %%
blue_array = np.array(blue_lenna)
print(type(blue_array))

# %%
blue_array[:,:,2] = 0
plt.figure(figsize=(10,10))
plt.imshow(blue_array)
plt.show()

# %%
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=440x440 at 0x7F868046BE50>

# %%
blue_array = np.array(blue_lenna)
print(type(blue_array))
# Out:
# <class 'numpy.ndarray'>

# %%
blue_array[:,:,2] = 0
plt.figure(figsize=(10,10))
plt.imshow(blue_array)
plt.show()
