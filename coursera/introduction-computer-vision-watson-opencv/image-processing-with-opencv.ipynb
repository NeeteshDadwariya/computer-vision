# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
baboon_blue = cv2.imread("../../images/baboon.png")

# %%
boboon_blue_rgb = cv2.cvtColor(baboon_blue, cv2.COLOR_BGR2RGB)

# %%
baboon_blue_rgb2 =boboon_blue_rgb.copy()
baboon_blue_rgb2[:,:,2] = 0
plt.figure(figsize=(10,10))
plt.imshow(baboon_blue_rgb2)
plt.show()
